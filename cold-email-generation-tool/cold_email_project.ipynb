# %%
pip install groq
# Out:
# Collecting groq
#   Downloading groq-0.23.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from groq) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from groq) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from anyio<5,>=3.5.0->groq) (3.6)
# Requirement already satisfied: certifi in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->groq) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from httpx<1,>=0.23.0->groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from pydantic<3,>=1.9.0->groq) (2.20.1)
# Downloading groq-0.23.1-py3-none-any.whl (127 kB)
# Installing collected packages: groq
# Successfully installed groq-0.23.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.3.24-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-core<1.0.0,>=0.3.55 (from langchain)
#   Downloading langchain_core-0.3.56-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain)
#   Downloading langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith<0.4,>=0.1.17 (from langchain)
#   Downloading langsmith-0.3.38-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.27.0)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.1.17->langchain)
#   Downloading orjson-3.10.16-cp312-cp312-win_amd64.whl.metadata (42 kB)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langchain) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langchain) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: anyio in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain) (2.4)
# Downloading langchain-0.3.24-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 11.9 MB/s eta 0:00:00
# Downloading langchain_core-0.3.56-py3-none-any.whl (437 kB)
# Downloading langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Downloading langsmith-0.3.38-py3-none-any.whl (359 kB)
# Downloading orjson-3.10.16-cp312-cp312-win_amd64.whl (133 kB)
# Installing collected packages: orjson, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed langchain-0.3.24 langchain-core-0.3.56 langchain-text-splitters-0.3.8 langsmith-0.3.38 orjson-3.10.16
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-0.3.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.49 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langchain-groq) (0.3.56)
# Requirement already satisfied: groq<1,>=0.4.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langchain-groq) (0.23.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.11.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (0.3.38)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (23.2)
# Requirement already satisfied: idna>=2.8 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.6)
# Requirement already satisfied: certifi in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.49->langchain-groq) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (3.10.16)
# Requirement already satisfied: requests<3,>=2 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (2.31.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (2.1.0)
# Downloading langchain_groq-0.3.2-py3-none-any.whl (15 kB)
# Installing collected packages: langchain-groq
# Successfully installed langchain-groq-0.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_groq import ChatGroq

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0,
    groq_api_key='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',
    model_name ="llama-3.3-70b-versatile"
)
response = llm.invoke("the first person to write bhagavadgita...")
print(response.content)
# Out:
# The Bhagavad Gita is an ancient Indian text that is part of the Hindu epic, the Mahabharata. The authorship of the Bhagavad Gita is traditionally attributed to the sage Vyasa, who is said to have written the Mahabharata, including the Bhagavad Gita.
#
# However, the historical authorship of the Bhagavad Gita is a matter of debate among scholars. Some scholars believe that the text was written by multiple authors over a period of time, while others argue that it was written by a single author.
#
# The traditional view is that Vyasa dictated the Mahabharata, including the Bhagavad Gita, to the god Ganesha, who wrote it down. This view is based on the traditional Hindu belief that the Vedas and other sacred texts were revealed to ancient sages and seers, who then transmitted them to their disciples.
#
# In terms of historical evidence, the oldest surviving manuscripts of the Bhagavad Gita date back to the 5th or 6th century CE. However, scholars believe that the text was composed earlier, possibly between 400 BCE and 400 CE.
#
# Some of the key scholars who have contributed to our understanding of the Bhagavad Gita include:
#
# * Adi Shankara (8th century CE), who wrote a commentary on the Bhagavad Gita that is still widely studied today.
# * Ramanuja (11th century CE), who wrote a commentary on the Bhagavad Gita that emphasized the importance of devotion and surrender to God.
# * Madhva (13th century CE), who wrote a commentary on the Bhagavad Gita that emphasized the importance of knowledge and self-realization.
#
# Overall, while we do not know the name of the first person to write the Bhagavad Gita, the text has been widely studied and commented upon by many scholars and sages over the centuries, and its teachings continue to be an important part of Hindu philosophy and spirituality.

# %%
pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (1.0.7)
# Requirement already satisfied: build>=1.0.3 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (2.8.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi==0.115.9 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.2)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (4.0.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (1.21.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (1.32.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (1.32.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (0.53b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (1.32.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (0.15.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (3.10.16)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from chromadb) (4.20.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: packaging>=19.1 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from httpx>=0.27.0->chromadb) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from httpx>=0.27.0->chromadb) (3.6)
# Requirement already satisfied: sniffio in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from jsonschema>=4.19.0->chromadb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from jsonschema>=4.19.0->chromadb) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from jsonschema>=4.19.0->chromadb) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from jsonschema>=4.19.0->chromadb) (0.15.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.39.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.31.0)
# Requirement already satisfied: requests-oauthlib in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.1.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.2)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.32.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.32.1)
# Requirement already satisfied: opentelemetry-proto==1.32.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.32.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.53b1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.53b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.53b1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.53b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.53b1)
# Requirement already satisfied: opentelemetry-util-http==0.53b1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.53b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from opentelemetry-instrumentation==0.53b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from opentelemetry-instrumentation-asgi==0.53b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from pydantic>=1.9->chromadb) (2.20.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->chromadb) (2.17.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.30.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: filelock in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bhoom\appdata\roaming\python\python312\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\bhoom\downloads\jyp notebook\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.
